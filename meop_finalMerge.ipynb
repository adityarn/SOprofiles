# %%
import pandas as pd
import numpy as np
import glob

# %%
# Get a list of all CSV files in the directory
path = '/scratch/an1n23/meop_RS_AS/'  # Change to your path
all_files = glob.glob(path + "/*.part")

# %%
all_files
# Out:
# ['/scratch/an1n23/meop_RS_AS/36.part',
#  '/scratch/an1n23/meop_RS_AS/24.part',
#  '/scratch/an1n23/meop_RS_AS/20.part',
#  '/scratch/an1n23/meop_RS_AS/35.part',
#  '/scratch/an1n23/meop_RS_AS/23.part',
#  '/scratch/an1n23/meop_RS_AS/34.part',
#  '/scratch/an1n23/meop_RS_AS/22.part',
#  '/scratch/an1n23/meop_RS_AS/13.part',
#  '/scratch/an1n23/meop_RS_AS/33.part',
#  '/scratch/an1n23/meop_RS_AS/16.part',
#  '/scratch/an1n23/meop_RS_AS/12.part',
#  '/scratch/an1n23/meop_RS_AS/32.part',
#  '/scratch/an1n23/meop_RS_AS/27.part',
#  '/scratch/an1n23/meop_RS_AS/15.part',
#  '/scratch/an1n23/meop_RS_AS/31.part',
#  '/scratch/an1n23/meop_RS_AS/26.part',
#  '/scratch/an1n23/meop_RS_AS/09.part',
#  '/scratch/an1n23/meop_RS_AS/25.part',
#  '/scratch/an1n23/meop_RS_AS/21.part']

# %%
dfs = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    dfs.append(df)

meop = pd.concat(dfs, axis=0, ignore_index=True)

# %%
meop
# Out:
#          PLATFORM_NUMBER  PROFILE_NUMBER  TEMP_ADJUSTED  PSAL_ADJUSTED  \
# 0                  12354          826863       1.778462      33.675300
# 1                  12354          826863       1.767164      33.709420
# 2                  12354          826863       1.749170      33.762875
# 3                  12354          826863       1.734456      33.806213
# 4                  12354          826863       1.726231      33.829483
# ...                  ...             ...            ...            ...
# 8038215             8670          263598       1.613877            NaN
# 8038216             8670          263598       1.628112            NaN
# 8038217             8670          263598       1.547661            NaN
# 8038218             8670          263598       1.519314            NaN
# 8038219             8670          263598       1.546500            NaN
#
#          PRES_ADJUSTED  PRES_ADJUSTED_QC  PRES_ADJUSTED_ERROR  \
# ...

# %%
meop.to_csv("/home/an1n23/datasets/meop_RS_AS_merged.csv", index=False)
